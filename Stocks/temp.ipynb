# %%
from stocks import *
import matplotlib.pyplot as plt

# %%
a = stocks("GME")
a.update(True)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 a = stocks("GME")
# ----> 2 a.update(True)
#
# File c:\Users\atlas\Documents\GitHub\Uwu\Financial\Stocks\stocks.py:61, in stocks.update(self, force_news)
#      59 update_pair(self.tick)
#      60 if force_news:
# ---> 61     update_news_raw(self.tick)
#      62     update_labels(self.tick)
#
# File c:\Users\atlas\Documents\GitHub\Uwu\Financial\Stocks\update.py:88, in update_news_raw(tick, path)
#      85 n1, name1 = news1(tick)
#      86 update_news_h(n1,path,name1)
# ---> 88 n2, name2 = news2(tick)
#      89 update_news_h(n2,path,name2)
#
# File c:\Users\atlas\Documents\GitHub\Uwu\Financial\Stocks\news_utils.py:191, in news2(tick)
#     184 mon = {'Jan': 1,'Feb': 2,'Mar': 3,
#     185             'Apr': 4, 'May': 5, 'Jun': 6,
#     186             'Jul': 7, 'Aug': 8, 'Sep': 9,
# ...
